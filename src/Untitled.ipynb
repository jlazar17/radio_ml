# %%
import cv2

# %%
im = cv2.imread("/Users/jlazar/Desktop/dumb_jeff.jpeg")/256

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(np.round(im[:, :, 0]), interpolation="none", cmap="Reds")

# %%
plt.imshow(np.round(im[:, :, 1]), interpolation="none", cmap="Greens")

# %%
plt.imshow(np.round(im[:, :, 2]), interpolation="none", cmap="Blues")
